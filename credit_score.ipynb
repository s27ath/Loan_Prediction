# %%
import pandas as pd

# %%
PATH='/content/drive/MyDrive/data/credit_score'
df=pd.read_csv(PATH)

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# ...

# %%
df.tail()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              895
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
df['person_emp_length']=df['person_emp_length'].fillna(df['person_emp_length'].median())
df['loan_int_rate']=df['loan_int_rate'].fillna(df['loan_int_rate'].mean())

# %%
df.shape
# Out:
# (32581, 12)

# %%
df.isnull().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_status                   0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %% [markdown]
# Univariate Analysis

# %% [markdown]
# Analyzing persons age

# %%
print(df['person_age'].max())
print(df['person_age'].min())
print(df['person_age'].mean())
print(df['person_age'].median())
print(df['person_age'].std())
# Out:
# 144
# 20
# 27.73459992019889
# 26.0
# 6.348078419225359

# %%
df['person_age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['person_age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# As we can see from the box plot that most of the people age range is between 20 to 35 and credit should be granted favorably only to older people as they will have more credit history and more experience of managing financial expenses

# %% [markdown]
# Analyzing person_income

# %%
print(df['person_income'].max())
print(df['person_income'].min())
print(df['person_income'].mean())
print(df['person_income'].median())
print(df['person_income'].std())
# Out:
# 6000000
# 4000
# 66074.84846996715
# 55000.0
# 61983.11916815907

# %%
df['person_income'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['person_income'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Here the highest income earned is 60 lakhs and the lowest income earned is   4000.Therefore credit should be given to people with higher income

# %% [markdown]
# Analyzing person_home_ownership

# %%
df['person_home_ownership'].mode()
# Out:
# 0    RENT
# Name: person_home_ownership, dtype: object

# %%
df['person_home_ownership'].value_counts()
# Out:
# RENT        16446
# MORTGAGE    13444
# OWN          2584
# OTHER         107
# Name: person_home_ownership, dtype: int64

# %%
df['person_home_ownership'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Most of the people in the data set rent there houses which is an additional expense on a whole.Therefore for all the people who rent a house,for them all the factors should carefully analyzed and credit should be given

# %% [markdown]
# Analyzing  person_emp_length

# %%
print(df['person_emp_length'].max())
print(df['person_emp_length'].min())
print(df['person_emp_length'].mean())
print(df['person_emp_length'].median())
print(df['person_emp_length'].std())
# Out:
# 123.0
# 0.0
# 4.767993615911114
# 4.0
# 4.0873716782070915

# %%
df['person_emp_length'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# As we see from the box plot the average of emplyment length is 5 years which inturn is a sign of good income source and stability.

# %% [markdown]
# analyzing loan_intent

# %%
print(df['loan_intent'].mode())
# Out:
# 0    EDUCATION
# Name: loan_intent, dtype: object

# %%
df['loan_intent'].value_counts()
# Out:
# EDUCATION            6453
# MEDICAL              6071
# VENTURE              5719
# PERSONAL             5521
# DEBTCONSOLIDATION    5212
# HOMEIMPROVEMENT      3605
# Name: loan_intent, dtype: int64

# %%
df['loan_intent'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# As we can see from the histogram most of the loans are granted for education and medical purposes.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           32581 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               32581 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
# analyzing loan_grade

# %%
df['loan_grade'].mode()
# Out:
# 0    A
# Name: loan_grade, dtype: object

# %%
df['loan_grade'].value_counts()
# Out:
# A    10777
# B    10451
# C     6458
# D     3626
# E      964
# F      241
# G       64
# Name: loan_grade, dtype: int64

# %%
df['loan_grade'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# As we can see from the bar plot that most of the loan grades are A which means that they are credit worthy.

# %% [markdown]
# analyzing loan_amnt

# %%
print(df['loan_amnt'].max())
print(df['loan_amnt'].min())
print(df['loan_amnt'].mean())
print(df['loan_amnt'].median())
print(df['loan_amnt'].std())
# Out:
# 35000
# 500
# 9589.371105859243
# 8000.0
# 6322.086645792259

# %%
df['loan_amnt'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# higher loan amounts means higher risk or getting back the amount and higher intrest rate.Therefore individuals with higher loan amount and higher intrest rate should be carefully monitored and assesed before lending credit

# %% [markdown]
# Analyzing loan_int_rate

# %%
print(df['loan_int_rate'].max())
print(df['loan_int_rate'].min())
print(df['loan_int_rate'].mean())
print(df['loan_int_rate'].median())
print(df['loan_int_rate'].std())
# Out:
# 23.22
# 5.42
# 11.011694892245037
# 11.011694892245036
# 3.0816045462400004

# %%
df['loan_int_rate'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['loan_int_rate'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Analyzing loan_percent_income

# %%
print(df['loan_percent_income'].max())
print(df['loan_percent_income'].min())
print(df['loan_percent_income'].mean())
print(df['loan_percent_income'].median())
print(df['loan_percent_income'].std())
# Out:
# 0.83
# 0.0
# 0.1702034928332464
# 0.15
# 0.10678175634492382

# %%
df['loan_percent_income'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['loan_percent_income'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# On an AVG its 0.17% of loan percent income.People with higher loan percent income should not be given any credit

# %% [markdown]
#  Analyzing cb_person_default_on_file

# %%
print(df['cb_person_default_on_file'].mode())
# Out:
# 0    N
# Name: cb_person_default_on_file, dtype: object

# %%
df['cb_person_default_on_file'].value_counts()
# Out:
# N    26836
# Y     5745
# Name: cb_person_default_on_file, dtype: int64

# %%
df['cb_person_default_on_file'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# As we can understand from the bar plot that majority of the individuals have no defaults on there credit history.

# %% [markdown]
# Analyzing cb_person_cred_hist_length

# %%
print(df['cb_person_cred_hist_length'].max())
print(df['cb_person_cred_hist_length'].min())
print(df['cb_person_cred_hist_length'].mean())
print(df['cb_person_cred_hist_length'].median())
print(df['cb_person_cred_hist_length'].std())
# Out:
# 30
# 2
# 5.804211043246064
# 4.0
# 4.055001164712727

# %%
df['cb_person_cred_hist_length'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# As we can see from the boxplot that on a avg the persons credit history length is 5 years.More the credit history length more the financial clarity on the person on the financial stability.

# %% [markdown]
# Bivariate Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           32581 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               32581 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
# Analyzing age and loan status

# %%
df.boxplot(by='loan_status',column='person_age')
# Out:
# <Axes: title={'center': 'person_age'}, xlabel='loan_status'>

# %% [markdown]
# min age is 20 and max age is 144 and people in the age range of 20-40 are applying loans and there are lots of outliers for the age above 40

# %% [markdown]
# Analyzing income and loan status

# %%
df.boxplot(by='loan_status',column='person_income')
# Out:
# <Axes: title={'center': 'person_income'}, xlabel='loan_status'>

# %% [markdown]
# Analyzing person_home_ownership  and loan status

# %%
loan_home=df.groupby(['person_home_ownership','loan_status']).size().unstack()
loan_home.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='person_home_ownership'>

# %% [markdown]
# As we can see that there are 4 types of home owner ship and highest number of credit defaults are happening in rents.Therefore the credit should carefully given to people renting a house

# %% [markdown]
# Analyzing person_emp_length and loan status

# %%
df.boxplot(by='loan_status',column='person_emp_length')
# Out:
# <Axes: title={'center': 'person_emp_length'}, xlabel='loan_status'>

# %% [markdown]
# Analyzing loan_intent and loan status

# %%
loan_intent=df.groupby(['loan_intent','loan_status']).size().unstack()
loan_intent.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='loan_intent'>

# %% [markdown]
# As we can see there are 6 types of loan intents and the highest credit lending is in education and medical and highest credit default is in debt consolidation and medical

# %% [markdown]
# Analyzing loan_grade and loan_status

# %%
loan_grade=df.groupby(['loan_grade','loan_status']).size().unstack()
loan_grade.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='loan_grade'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           32581 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               32581 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
# Analyzing loan_amt and loan_status

# %%
df.boxplot(by='loan_status',column='loan_amnt')
# Out:
# <Axes: title={'center': 'loan_amnt'}, xlabel='loan_status'>

# %% [markdown]
# As we can understand from the boxplot when there is more income there are more defaults in credit

# %% [markdown]
# Analyzing loan_int_rate and loan_status

# %%
df.boxplot(by='loan_status',column='loan_int_rate')
# Out:
# <Axes: title={'center': 'loan_int_rate'}, xlabel='loan_status'>

# %% [markdown]
# As we can understand more int rates lead to more credit defaults

# %% [markdown]
# Analyzing loan_percent_income and loan_status

# %%
df.boxplot(by='loan_status',column='loan_percent_income')
# Out:
# <Axes: title={'center': 'loan_percent_income'}, xlabel='loan_status'>

# %% [markdown]
# As we can understand if more percent of persons income is dedicated for payment of loans more number of defaults are happening

# %% [markdown]
# Analyzing cb_person_default_on_file and loan_status

# %%
loan_default=df.groupby(['cb_person_default_on_file','loan_status']).size().unstack()
loan_default.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='cb_person_default_on_file'>

# %% [markdown]
# As we can understand there are more non defaults than defaults

# %% [markdown]
# Analyzing cb_person_cred_hist_length and loanstatus

# %%
df.boxplot(by='loan_status',column='cb_person_cred_hist_length')
# Out:
# <Axes: title={'center': 'cb_person_cred_hist_length'}, xlabel='loan_status'>

# %% [markdown]
# Credit history of defaults and non defaults are the same

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-194-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
import seaborn as sns
